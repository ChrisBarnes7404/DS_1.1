# %% [markdown]
# # Ninja Warrior Dataset Exploration

# %% [markdown]
# ### DESCRIPTION: Obstacle history of American Ninja Warrior seasons 1-10
# #### Dataset: https://data.world/ninja/anw-obstacle-history
#
# #### SUMMARY
# This dataset includes every obstacle in the history of American Ninja Warrior from season 1 to 10. This includes the obstacles at Sasuke (also known as the original Ninja Warrior in Japan) during seasons 1-3 when American Ninja Warrior (ANW) was on G4, and the top 10 competitors from the semi-finals round of ANW were sent to Sasuke to compete. Starting in season 4 of ANW, which is known as the "NBC era" when the show took on the regional/city formats for both qualifying and semi-final rounds with the finalists from each region competing at the National Finals of ANW in Las Vegas.
#
# Credit to Sasukepedia as the [original source](https://sasukepedia.fandom.com/wiki/List_of_American_Ninja_Warrior_obstacles)

# %%
# Pandas is a library for basic data analysis
import pandas as pd

# NumPy is a library for advanced mathematical computation
import numpy as np

# MatPlotLib is a library for basic data visualization
import matplotlib.pyplot as plt

# SeaBorn is a library for advanced data visualization
import seaborn as sns

from scipy import stats

# Dataset from above
df = pd.read_csv('American Ninja Warrior Obstacle History.csv')
# .set_index('Season')
df
# Out:
#      Season   Location                Round/Stage     Obstacle Name  \
# 0         1     Venice                 Qualifying   Quintuple Steps
# 1         1     Venice                 Qualifying        Rope Swing
# 2         1     Venice                 Qualifying    Rolling Barrel
# 3         1     Venice                 Qualifying    Jumping Spider
# 4         1     Venice                 Qualifying       Pipe Slider
# ..      ...        ...                        ...               ...
# 884      10  Las Vegas  National Finals - Stage 3  Curved Body Prop
# 885      10  Las Vegas  National Finals - Stage 3         Peg Cloud
# 886      10  Las Vegas  National Finals - Stage 3         Time Bomb
# 887      10  Las Vegas  National Finals - Stage 3         Cane Lane
# 888      10  Las Vegas  National Finals - Stage 4        Rope Climb
#
#      Obstacle Order
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
# ..              ...
# ...

# %% [markdown]
# ### Questions to Consider Answering
#
# - What sorts of information does this dataset contain?
#     Season	Location	Round/Stage	Obstacle Name	Obstacle Order
# ---
# - What kinds of questions might we be able to answer with this data?
#     - What was the most occuring obstical? (per season?)
#     - How Many Seasons are Recorded in This Dataset?
#     - Which Season(s) had the most obsticals?
#     - What location(s) had the most obsticals?
#     - Which obstacles presisted over seasons?
# ---
# - What kinds of questions can’t we answer with this data?
#     - The speed at which each obstical was compelted under.
#     - Which obsticales were compelted.
#     - Who Competed.
# - What sorts of information might be actionable?

# %% [markdown]
# ### How Many Unique Locations, Stages, Obsticals and Seasons are Recorded in This Dataset?

# %%
df.nunique()
# Out:
# Season             10
# Location           30
# Round/Stage         8
# Obstacle Name     225
# Obstacle Order     10
# dtype: int64

# %% [markdown]
# There are 10 Seasons, each broken into 8 Stages.
#
# Spread across 30 diffeerent locations.
#
# Consisting of 225 Unique Obsticales in 10 different positions thorughout each stage.

# %% [markdown]
# ## What was the most occuring obstical?

# %%
plt.show(sns.heatmap(pd.crosstab(df["Obstacle Name"], df["Season"], normalize='index'), cmap="Blues"))

# %%
# What was the most occuring obstical
for i in range(10):
    print("Season ", i+1)
    print(df[df["Season"] == i+1]["Obstacle Name"].describe())
    print("---------------")
df["Obstacle Name"].describe()
# Out:
# Season  1
# count                 40
# unique                31
# top       Jumping Spider
# freq                   3
# Name: Obstacle Name, dtype: object
# ---------------
# Season  2
# count                 38
# unique                30
# top       Jumping Spider
# freq                   3
# Name: Obstacle Name, dtype: object
# ---------------
# Season  3
# count              38
# unique             30
# top       Warped Wall
# freq                3
# Name: Obstacle Name, dtype: object
# ---------------
# Season  4
# count             118
# unique             41
# top       Warped Wall
# freq               13
# Name: Obstacle Name, dtype: object
# ---------------
# Season  5
# count              88
# unique             51
# top       Warped Wall
# freq                9
# Name: Obstacle Name, dtype: object
# ---------------
# Season  6
# count             104
# unique             57
# top       Warped Wall
# freq               11
# Name: Obstacle Name, dtype: object
# ...

# %% [markdown]
# ### The Warped Wall Obstical Appeared The Most, With a Frequency of 86 Occurances over the 10 Seasons

# %% [markdown]
# ## Which Season had the Most Obsticals?

# %%
print(df['Season'].value_counts().sort_index())
# Out:
# 1      40
# 2      38
# 3      38
# 4     118
# 5      88
# 6     104
# 7     120
# 8     103
# 9     120
# 10    120
# Name: Season, dtype: int64

# %% [markdown]
# ### Seasons 7, 9, & 10 had the most obsticals of 120

# %% [markdown]
# ## What Location had the Most Obsticals?

# %%
print(df['Location'].value_counts())
# Out:
# Las Vegas               167
# Venice                   93
# Denver                   48
# Los Angeles              48
# Miami                    48
# Philadelphia             32
# Indianapolis             32
# Kansas City              32
# Dallas                   32
# Sasuke 23 (Japan)        25
# Sasuke 27 (Japan)        23
# Sasuke 26 (Japan)        23
# Northeast                17
# Southeast                17
# Daytona Beach            16
# Baltimore                16
# Pittsburgh               16
# San Pedro (Military)     16
# Houston                  16
# San Antonio              16
# Orlando                  16
# Cleveland                16
# Atlanta                  16
# Minneapolis              16
# Oklahoma City            16
# St. Louis                16
# Southwest                15
# Northwest                15
# Mid-South                15
# Midwest                  15
# Name: Location, dtype: int64

# %% [markdown]
# ### Las Vegas Clearly has the most sitting at 167

# %%
# df.groupby(["Round/Stage"])["Location"].value_counts().unstack().plot(
#             kind='bar', stacked=False)

# df.groupby(["Round/Stage"])["Location"].value_counts().unstack().plot(
#             kind='bar', stacked=True)

# df.groupby(["Location"])["Round/Stage"].value_counts().unstack().plot(
#             kind='bar', stacked=False)

df.groupby(["Location"])["Round/Stage"].value_counts().unstack().plot(
            kind='bar', stacked=True)

# %% [markdown]
# ### Most Locations only hosted Qualifiying(pink) and Final(blue) Rounds for their Region/City,
# ### And Venice Held the Qulifying(brown), Semi-Final(gray), and their regional Final(blue),
# ### While Las Vegas and Sasuke 23, 26, 27 Held the National Finals with the majority of them held in Las Vegas

# %% [markdown]
# ### How Did The Obsticals Position Vary?

# %%
print(df["Obstacle Name"].nunique())
df["Obstacle Name"].unique()
# Out:
# 225
# array(['Quintuple Steps', 'Rope Swing', 'Rolling Barrel',
#        'Jumping Spider', 'Pipe Slider', 'Warped Wall', 'Tarzan Swing',
#        'Jumping Bars', 'Cargo Climb', 'Twelve Timbers', 'Curtain Slider',
#        'Log Grip', 'Half-Pipe Attack', 'Slider Jump', 'Tarzan Rope',
#        'Rope Ladder', 'Downhill Jump', 'Salmon Ladder', 'Stick Slider',
#        'Unstable Bridge', 'Metal Spin', 'Wall Lift', 'Arm Rings',
#        'Descending Lamp Grasper', 'Devil Steps', 'Shin Cliffhanger',
#        'Hang Climb', 'Spider Flip', 'Gliding Ring', 'Heavenly Ladder',
#        'G-Rope', 'Quad Steps', 'Bridge of Blades', 'Circle Slider',
#        'Step Slider', 'Hazard Swing', 'Rolling Escargot', 'Giant Swing',
#        'Slider Drop', 'Double Salmon Ladder', 'Balance Tank',
#        'Roulette Cylinder', 'Doorknob Grasper', 'Cycle Road',
#        'Ultimate Cliffhanger', 'Swing Circle', 'Bungee Rope Climb',
#        'Flying Bar', 'Rope Climb', 'Jump Hang', 'Spinning Bridge',
# ...

# %% [markdown]
# # Warped Wall
# ![warped_wall](KC_Warped_Wall.gif)
# # Salmon Ladder
# ![salmon_ladder](salmon_ladder.gif)

# %%
# The idea was to group the obstacles by their name and season with a statement like 
# df.groupby("Obstacle Name")["Season"].

# This dataframe should then allow you to see each season an obstacle was included in and
# for how many seasons they were included in, allowing you to summarize which obstacle persisted
# over the seasons and maybe their reasons for why.  
# (Maybe even show a pie chart that shows the % an obstacle was used in every season of the show)

t = df.groupby("Obstacle Name")["Season"].describe()
t
# Out:
#                       count  mean       std   min    25%   50%    75%   max
# Obstacle Name
# (Modified) Ring Toss    2.0   7.0  0.000000   7.0   7.00   7.0   7.00   7.0
# Archer Alley            1.0  10.0       NaN  10.0  10.00  10.0  10.00  10.0
# Archer Steps            6.0  10.0  0.000000  10.0  10.00  10.0  10.00  10.0
# Area 51                 1.0   7.0       NaN   7.0   7.00   7.0   7.00   7.0
# Arm Bike                1.0   3.0       NaN   3.0   3.00   3.0   3.00   3.0
# ...                     ...   ...       ...   ...    ...   ...    ...   ...
# Wheel Flip              2.0  10.0  0.000000  10.0  10.00  10.0  10.00  10.0
# Wind Chimes             2.0   7.0  0.000000   7.0   7.00   7.0   7.00   7.0
# Window Hang             1.0   8.0       NaN   8.0   8.00   8.0   8.00   8.0
# Wingnut Alley           2.0   9.5  0.707107   9.0   9.25   9.5   9.75  10.0
# Wingnuts                4.0   9.5  0.577350   9.0   9.00   9.5  10.00  10.0
#
# [225 rows x 8 columns]

# %%
plt.show(sns.heatmap(pd.crosstab(df["Obstacle Name"], df["Obstacle Order"], normalize='index'), cmap="Blues"))

# %%
for i in range(10):
    s = df[df['Season'] == i+1]
    
    sns.catplot(x="Obstacle Name", hue="Obstacle Order",
                data=s, kind="count", height=4, aspect=10);
#     sns.lineplot(x="Obstacle Name", y="Obstacle Order", hue="Season", data=s)

# %%
stats.describe(df.describe())
# Out:
# DescribeResult(nobs=8, minmax=(array([1., 1.]), array([889., 889.])), mean=array([116.12460606, 114.89507021]), variance=array([97533.78373562, 97842.65809398]), skewness=array([2.26734599, 2.26742547]), kurtosis=array([3.14174684, 3.14194388]))

# %% [markdown]
# ## Question Summary  & Conclusions
#
# ### 1: How Many Unique Locations, Stages, Obsticals and Seasons are Recorded in This Dataset?
# There are 10 Seasons, each broken into 8 Stages.
#
# Spread across 30 diffeerent locations.
#
# Consisting of 225 Unique Obsticales in 10 different positions thorughout each stage.
#
# ### 2: What was the most occuring obstical? (per season?)
# The Warped Wall Obstical Appeared The Most, With a Frequency of 86 Occurances over the 10 Seasons
#
# ### 3: Which Season(s) had the most obsticals?
# Seasons 7, 9, & 10 had the most obsticals of 120
#
# ### 4: What location(s) had the most obsticals?
# Las Vegas Clearly has the most sitting at 167
#
#   - Most Locations only hosted Qualifiying(pink) and Final(blue) Rounds for their Region/City,
#   - And Venice Held the Qulifying(brown), Semi-Final(gray), and their regional Final(blue),
#   - While Las Vegas and Sasuke 23, 26, 27 Held the National Finals with the majority of them held in Las Vegas
#
#
# ### 5: Which obstacles presisted over seasons?

# %% [markdown]
# ![rubric](rubric.png)

# %%
# f,(ax_count, ax_stack) = plt.subplots(2,
#             gridspec_kw={"height_ratios": (.5, .5)})

# df.groupby(["Obstacle Name"])["Season"].value_counts().unstack().plot(
#             kind='bar', stacked=True, ax=ax_stack)
# sns.countplot(x="Obstacle Name", hue="Season",
#             data=df.sort_values("Obstacle Name"), ax=ax_count)
# plt.show()

# sns.catplot(x="Season", hue="Obstacle Name",
#             data=df, kind="count",
#             height=4, aspect=4);
