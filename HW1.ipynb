# %% [markdown]
# # Write Custom Function to Compute Histogram for a Numerical Array
#
# * You can use numpy
# * Your function takes two arguments: 1- list 2- interval
# * Your function would return a dictionary with intervals as keys and how many of elements in list are in the intervals as values

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Datasets/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # For visualization part, you should elaborate on the following

# %%
# histogram function

def custom_hist(ls, interval):
    hist_ls_dict = dict()
    min_ls = np.min(ls)
    max_ls = np.max(ls)
    I = (max_ls - min_ls) / interval
    ls = sorted(ls)

#     print(ls, "\n")
    
    
    hist = {}
    for i in ls:
        hist[i] = hist.get(i, 0) + 1
#     print(hist, "\n")
    
#     print(hist.keys())
#     print("-------------")
#     print(hist.values())
#     print()
    
    """
    0.42: 1, 0.67: 1, 0.75: 2, 0.83: 2, 0.92: 1,
    1.0: 7, 2.0: 10, 3.0: 6, 4.0: 10, 5.0: 4,
    6.0: 3, 7.0: 3, 8.0: 4, 9.0: 8, 10.0: 2,
    11.0: 4, 12.0: 1, 13.0: 2, 14.0: 6, 14.5: 1,
    15.0: 5, 16.0: 17, 17.0: 13, 18.0: 26, 19.0: 25,
    20.0: 15, 20.5: 1, 21.0: 24, 22.0: 27, 23.0: 15,
    23.5: 1, 24.0: 30, 24.5: 1, 25.0: 23, 26.0: 18,
    27.0: 18, 28.0: 25, 28.5: 2, 29.0: 20, 30.0: 25,
    30.5: 2, 31.0: 17, 32.0: 18, 32.5: 2, 33.0: 15,
    34.0: 15, 34.5: 1, 35.0: 18, 36.0: 22, 36.5: 1,
    37.0: 6, 38.0: 11, 39.0: 14, 40.0: 13, 40.5: 2,
    41.0: 6, 42.0: 13, 43.0: 5, 44.0: 9, 45.0: 12,
    45.5: 2, 46.0: 3, 47.0: 9, 48.0: 9, 49.0: 6,
    50.0: 10, 51.0: 7, 52.0: 6, 53.0: 1, 54.0: 8,
    55.0: 2, 55.5: 1, 56.0: 4, 57.0: 2, 58.0: 5,
    59.0: 2, 60.0: 4, 61.0: 3, 62.0: 4, 63.0: 2,
    64.0: 2, 65.0: 3, 66.0: 1, 70.0: 2, 70.5: 1,
    71.0: 2, 74.0: 1, 80.0: 1  
    """
    
    print("To have", interval, " bins between", max_ls, " and", min_ls, " we need each to have ", np.ceil(I), " elements \n")
    
    return hist
#     return hist_ls_dict
    
print(custom_hist(df['Age'].dropna().values, 16))
# Out:
# To have 16  bins between 80.0  and 0.42  we need each to have  5.0  elements
#
# {0.42: 1, 0.67: 1, 0.75: 2, 0.83: 2, 0.92: 1, 1.0: 7, 2.0: 10, 3.0: 6, 4.0: 10, 5.0: 4, 6.0: 3, 7.0: 3, 8.0: 4, 9.0: 8, 10.0: 2, 11.0: 4, 12.0: 1, 13.0: 2, 14.0: 6, 14.5: 1, 15.0: 5, 16.0: 17, 17.0: 13, 18.0: 26, 19.0: 25, 20.0: 15, 20.5: 1, 21.0: 24, 22.0: 27, 23.0: 15, 23.5: 1, 24.0: 30, 24.5: 1, 25.0: 23, 26.0: 18, 27.0: 18, 28.0: 25, 28.5: 2, 29.0: 20, 30.0: 25, 30.5: 2, 31.0: 17, 32.0: 18, 32.5: 2, 33.0: 15, 34.0: 15, 34.5: 1, 35.0: 18, 36.0: 22, 36.5: 1, 37.0: 6, 38.0: 11, 39.0: 14, 40.0: 13, 40.5: 2, 41.0: 6, 42.0: 13, 43.0: 5, 44.0: 9, 45.0: 12, 45.5: 2, 46.0: 3, 47.0: 9, 48.0: 9, 49.0: 6, 50.0: 10, 51.0: 7, 52.0: 6, 53.0: 1, 54.0: 8, 55.0: 2, 55.5: 1, 56.0: 4, 57.0: 2, 58.0: 5, 59.0: 2, 60.0: 4, 61.0: 3, 62.0: 4, 63.0: 2, 64.0: 2, 65.0: 3, 66.0: 1, 70.0: 2, 70.5: 1, 71.0: 2, 74.0: 1, 80.0: 1}

# %%
import matplotlib.pyplot as plt

hist_dict = custom_hist(df['Age'].dropna().values, 16)

plt.bar(hist_dict.keys(), hist_dict.values())
plt.show()
# Out:
# To have 16  bins between 80.0  and 0.42  we need each to have  5.0  elements

# %% [markdown]
# ## Q2: How we can plot histogram of Age for female and male with legend?
# Use Pandas with .groupby method and plot the following

# %%
df.groupby('Sex')['Age'].plot(kind='hist', bins=16, legend=True, alpha=0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object
